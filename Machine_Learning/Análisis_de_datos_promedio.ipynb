# %% [markdown]
# <a href="https://colab.research.google.com/github/CaldeCrack/Little-Projects/blob/main/Machine_Learning/An%C3%A1lisis_de_datos_promedio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Inicialización
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ruta = "data.csv"
df = pd.read_csv(ruta)
df = df.loc[:, ~df.columns.str.match("^Unnamed")]

# %% [markdown]
# # Análisis

# %%
# Dataframes para casos malignos y benignos por separado
df_maligno = df[df["diagnosis"] == "M"]
df_benigno = df[df["diagnosis"] == "B"]

# %% [markdown]
# # radius_mean

# %%
df_maligno["radius_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["radius_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # texture_mean

# %%
df_maligno["texture_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["texture_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # perimeter_mean

# %%
df_maligno["perimeter_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["perimeter_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # area_mean

# %%
df_maligno["area_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["area_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # smoothness_mean

# %%
df_maligno["smoothness_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["smoothness_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # compactness_mean

# %%
df_maligno["compactness_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["compactness_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # concavity_mean

# %%
df_maligno["concavity_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["concavity_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # concave_points_mean

# %%
df_maligno["concave points_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["concave points_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # symmetry_mean

# %%
df_maligno["symmetry_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["symmetry_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # fractal_dimension_mean

# %%
df_maligno["fractal_dimension_mean"].plot(kind = "density", grid = False)

# %%
df_benigno["fractal_dimension_mean"].plot(kind = "density", grid = False)

# %% [markdown]
# # Conclusiones
# Son relevantes:
#
# - Casi todos xd
#
# Quiza no son relevantes:
#
# - texture_mean
# - smoothness_mean
# - concavity_mean (diría que si es relevante pero tengo un poco de duda)
# - symmetry_mean
#
# No son relevantes:
#
# - fractal_dimension
